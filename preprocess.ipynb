# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import re
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

# %%
def cleaning(text):
    text = [txt.lower() for txt in re.findall(r'(?:^|(?<= ))[a-zA-Z]+(?= |$)', text)]

    return "no text" if len(text) == 0 else text

# %%
model = AutoModelForSequenceClassification.from_pretrained("kuzgunlar/electra-turkish-sentiment-analysis")
tokenizer = AutoTokenizer.from_pretrained("kuzgunlar/electra-turkish-sentiment-analysis")
sa = pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)

# %%
def foo(text):
    p = sa(text)
    return p[0]['score'] if p[0]['label'] == 'Positive' else 1-p[0]['score']

# %%
df = pd.read_csv("dataV2.csv", encoding="utf-16")

# %%
df['num_favorites'] = df['num_favorites'].apply(lambda x : str(x).replace(".", ""))
df['num_will_read'] = df['num_will_read'].apply(lambda x : str(x).split(".")[0])
df['num_is_read'] = df['num_is_read'].apply(lambda x : str(x).split(".")[0])
df['num_did_read'] = df['num_did_read'].apply(lambda x : str(x).split(".")[0])
df['num_comments'] = df['num_comments'].apply(lambda x : str(x).split(".")[0])
df['num_purchases'] = df['num_purchases'].apply(lambda x : str(x).replace(".", ""))

# %%
df.book = df.book.apply(lambda x: re.sub("[(@*&?].*[)@*&?]", "", x))
df = df[df.star != 0]
df.drop_duplicates()
# Out:
#            id                     book        writer  \
# 0      582550  Gece Yarısı Kütüphanesi     Matt Haig
# 1      582550  Gece Yarısı Kütüphanesi     Matt Haig
# 2      582550  Gece Yarısı Kütüphanesi     Matt Haig
# 3      582550  Gece Yarısı Kütüphanesi     Matt Haig
# 4      582550  Gece Yarısı Kütüphanesi     Matt Haig
# ...       ...                      ...           ...
# 36515  345165     Can Veren Pervaneler  Hayati İnanç
# 36516  345165     Can Veren Pervaneler  Hayati İnanç
# 36517  345165     Can Veren Pervaneler  Hayati İnanç
# 36518  345165     Can Veren Pervaneler  Hayati İnanç
# 36519  345165     Can Veren Pervaneler  Hayati İnanç
#
#                         publisher  num_pages num_comments num_favorites  \
# 0                DOMİNGO YAYINEVİ        283          782         25645
# 1                DOMİNGO YAYINEVİ        283          782         25645
# 2                DOMİNGO YAYINEVİ        283          782         25645
# 3                DOMİNGO YAYINEVİ        283          782         25645
# 4                DOMİNGO YAYINEVİ        283          782         25645
# ...                           ...        ...          ...           ...
# 36515  BABIALİ KÜLTÜR YAYINCILIĞI        230          474          4157
# 36516  BABIALİ KÜLTÜR YAYINCILIĞI        230          474          4157
# 36517  BABIALİ KÜLTÜR YAYINCILIĞI        230          474          4157
# 36518  BABIALİ KÜLTÜR YAYINCILIĞI        230          474          4157
# 36519  BABIALİ KÜLTÜR YAYINCILIĞI        230          474          4157
#
#       num_will_read num_is_read num_did_read  ... avg_rating  num_five_star  \
# 0                 2         361            2  ...       91.9            959
# 1                 2         361            2  ...       91.9            959
# 2                 2         361            2  ...       91.9            959
# 3                 2         361            2  ...       91.9            959
# 4                 2         361            2  ...       91.9            959
# ...             ...         ...          ...  ...        ...            ...
# 36515           588         108          752  ...       95.2            911
# 36516           588         108          752  ...       95.2            911
# 36517           588         108          752  ...       95.2            911
# 36518           588         108          752  ...       95.2            911
# 36519           588         108          752  ...       95.2            911
#
#        num_four_star  num_three_star  num_two_star  num_one_star  \
# 0                174              86            22            26
# 1                174              86            22            26
# 2                174              86            22            26
# 3                174              86            22            26
# 4                174              86            22            26
# ...              ...             ...           ...           ...
# 36515            121              42             7             9
# 36516            121              42             7             9
# 36517            121              42             7             9
# 36518            121              42             7             9
# 36519            121              42             7             9
#
#                                                  comment  price  \
# 0      Son zamanlarda sıkıntılı günler yaşayan Nora i...  48.11
# 1      “Her yaşam milyonlarca seçim ihtiva eder. Kimi...  48.11
# 2      Okunması çok rahat, kimi zaman genclik kitapla...  48.11
# 3       Okumanın bu kadar basit fakat verdiği mesajla...  48.11
# 4      Akıcı anlatımı ve sıra dışı hikayesiyle okuyuc...  48.11
# ...                                                  ...    ...
# 36515  Ruha şifa veren, İslam'dan beslenen beyitler. ...  42.00
# 36516  Lisedeyken tanışdığım ve o zamanlar anlamakta ...  42.00
# 36517  hayati baba, gönlünü dergah haline getirenleri...  42.00
# 36518  Hayati beyi sosyal medya sayesinde tanıdım, ki...  42.00
# 36519  Divan edebiyatına dair yazılar, şiirler barınd...  42.00
#
#                   type  star
# 0       Roman (çeviri)     5
# 1       Roman (çeviri)     5
# 2       Roman (çeviri)     5
# 3       Roman (çeviri)     5
# 4       Roman (çeviri)     5
# ...                ...   ...
# 36515  Divan Edebiyatı     5
# 36516  Divan Edebiyatı     5
# 36517  Divan Edebiyatı     5
# 36518  Divan Edebiyatı     4
# 36519  Divan Edebiyatı     5
#
# [36466 rows x 22 columns]

# %%
df.head()
# Out:
#        id                     book     writer         publisher  num_pages  \
# 0  582550  Gece Yarısı Kütüphanesi  Matt Haig  DOMİNGO YAYINEVİ        283
# 1  582550  Gece Yarısı Kütüphanesi  Matt Haig  DOMİNGO YAYINEVİ        283
# 2  582550  Gece Yarısı Kütüphanesi  Matt Haig  DOMİNGO YAYINEVİ        283
# 3  582550  Gece Yarısı Kütüphanesi  Matt Haig  DOMİNGO YAYINEVİ        283
# 4  582550  Gece Yarısı Kütüphanesi  Matt Haig  DOMİNGO YAYINEVİ        283
#
#   num_comments num_favorites num_will_read num_is_read num_did_read  ...  \
# 0          782         25645             2         361            2  ...
# 1          782         25645             2         361            2  ...
# 2          782         25645             2         361            2  ...
# 3          782         25645             2         361            2  ...
# 4          782         25645             2         361            2  ...
#
#   avg_rating  num_five_star  num_four_star  num_three_star  num_two_star  \
# 0       91.9            959            174              86            22
# 1       91.9            959            174              86            22
# 2       91.9            959            174              86            22
# 3       91.9            959            174              86            22
# 4       91.9            959            174              86            22
#
#    num_one_star                                            comment  price  \
# 0            26  Son zamanlarda sıkıntılı günler yaşayan Nora i...  48.11
# 1            26  “Her yaşam milyonlarca seçim ihtiva eder. Kimi...  48.11
# 2            26  Okunması çok rahat, kimi zaman genclik kitapla...  48.11
# 3            26   Okumanın bu kadar basit fakat verdiği mesajla...  48.11
# 4            26  Akıcı anlatımı ve sıra dışı hikayesiyle okuyuc...  48.11
#
#              type  star
# 0  Roman (çeviri)     5
# 1  Roman (çeviri)     5
# 2  Roman (çeviri)     5
# 3  Roman (çeviri)     5
# 4  Roman (çeviri)     5
#
# [5 rows x 22 columns]

# %%
df[['num_comments', 'num_favorites', 'num_will_read', 'num_is_read', 'num_did_read', 'num_purchases']] = df[['num_comments', 'num_favorites', 'num_will_read', 'num_is_read', 'num_did_read', 'num_purchases']].astype(int)

# %%
df.comment = df.comment.apply(cleaning)
df = df[df.comment != "no text"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35964 entries, 0 to 36519
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              35964 non-null  int64
#  1   book            35964 non-null  object
#  2   writer          35964 non-null  object
#  3   publisher       35964 non-null  object
#  4   num_pages       35964 non-null  int64
#  5   num_comments    35964 non-null  int32
#  6   num_favorites   35964 non-null  int32
#  7   num_will_read   35964 non-null  int32
#  8   num_is_read     35964 non-null  int32
#  9   num_did_read    35964 non-null  int32
#  10  num_purchases   35964 non-null  int32
#  11  num_ratings     35964 non-null  int64
#  12  avg_rating      35964 non-null  float64
#  13  num_five_star   35964 non-null  int64
#  14  num_four_star   35964 non-null  int64
#  15  num_three_star  35964 non-null  int64
#  16  num_two_star    35964 non-null  int64
#  17  num_one_star    35964 non-null  int64
#  18  comment         35964 non-null  object
#  19  price           35964 non-null  float64
#  20  type            35964 non-null  object
#  21  star            35964 non-null  int64
# dtypes: float64(2), int32(6), int64(9), object(5)
# memory usage: 5.5+ MB

# %%
df["positivity"] = df.comment.apply(foo)

# %%
df.to_csv("dataV4.csv", encoding='utf-16', index=False)
